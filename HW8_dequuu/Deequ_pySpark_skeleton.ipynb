# %%
# %env SPARK_VERSION=3.0.0 # TODO PUT YOUR VALUE
# Out:
# env: SPARK_VERSION=3.0.0 # TODO PUT YOUR VALUE

# %%
import pydeequ

from pyspark.sql import SparkSession, Row


# TODO create spark session with jdbc driver path
jdbc_driver_path = "/home/jovyan/work/mssql-jdbc-12.2.0.jre8.jar"
spark = SparkSession.builder \
    .appName("my-app-name") \
    .config("spark.driver.extraClassPath", jdbc_driver_path) \
    .config("spark.jars.packages", pydeequ.deequ_maven_coord) \
    .config("spark.jars.excludes", pydeequ.f2j_maven_coord) \
    .getOrCreate()

# %%
url = "jdbc:sqlserver://host.docker.internal:1433;databaseName=AdventureWorks2012;encrypt=false"

table = "Production.Product"
user = "NewLogin" # your user creds here
password  = "1234567890" # your user creds here

# TODO connect to DB with Spark using JDBC connection to read the data
df = spark.read.format("jdbc") \
    .option("url", url) \
    .option("dbtable", table) \
    .option("user", user) \
    .option("password", password) \
    .load()

# %%
### Data Analyzers section
# TODO analyze data here

from pydeequ.analyzers import *

analysisResult = AnalysisRunner(spark) \
                    .onData(df) \
                    .addAnalyzer(Size()) \
                    .addAnalyzer(Completeness("Color")) \
                    .addAnalyzer(ApproxCountDistinct("Color")) \
                    .addAnalyzer(Size("Color=='Black'")) \
                    .addAnalyzer(Mean("ReorderPoint")) \
                    .run()

analysisResult_df = AnalyzerContext.successMetricsAsDataFrame(spark, analysisResult)
analysisResult_df.show()
# Out:
# +-------+------------+--------------------+------------------+
# | entity|    instance|                name|             value|
# +-------+------------+--------------------+------------------+
# |Dataset|           *|Size (where: Colo...|              93.0|
# | Column|       Color|        Completeness|0.5079365079365079|
# | Column|       Color| ApproxCountDistinct|               9.0|
# |Dataset|           *|                Size|             504.0|
# | Column|ReorderPoint|                Mean|401.36309523809524|
# +-------+------------+--------------------+------------------+

# %%
### Data profiling section
# TODO profile data here


from pydeequ.profiles import *

result = ColumnProfilerRunner(spark) \
    .onData(df) \
    .run()

for col, profile in result.profiles.items():
    print(profile)
# Out:
# StandardProfiles for column: ModifiedDate: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 2,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null
# }
# NumericProfiles for column: ReorderPoint: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 6,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "45",
#             5,
#             0.00992063492063492
#         ],
#         [
#             "750",
#             156,
#             0.30952380952380953
#         ],
#         [
#             "375",
#             167,
#             0.33134920634920634
#         ],
#         [
#             "75",
#             97,
#             0.19246031746031747
#         ],
#         [
#             "600",
#             25,
#             0.0496031746031746
#         ],
#         [
#             "3",
#             54,
#             0.10714285714285714
#         ]
#     ],
#     "kll": "None",
#     "mean": 401.36309523809524,
#     "maximum": 750.0,
#     "minimum": 3.0,
#     "sum": 202287.0,
#     "stdDev": 280.306219151808,
#     "approxPercentiles": []
# }
# StandardProfiles for column: ProductLine: {
#     "completeness": 0.5515873015873016,
#     "approximateNumDistinctValues": 4,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 226,
#         "String": 278
#     },
#     "histogram": [
#         [
#             "NullValue",
#             226,
#             0.44841269841269843
#         ],
#         [
#             "R ",
#             100,
#             0.1984126984126984
#         ],
#         [
#             "M ",
#             91,
#             0.18055555555555555
#         ],
#         [
#             "S ",
#             35,
#             0.06944444444444445
#         ],
#         [
#             "T ",
#             52,
#             0.10317460317460317
#         ]
#     ]
# }
# StandardProfiles for column: Name: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 511,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 504
#     },
#     "histogram": null
# }
# StandardProfiles for column: rowguid: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 533,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 504
#     },
#     "histogram": null
# }
# StandardProfiles for column: SizeUnitMeasureCode: {
#     "completeness": 0.3492063492063492,
#     "approximateNumDistinctValues": 1,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 328,
#         "String": 176
#     },
#     "histogram": [
#         [
#             "NullValue",
#             328,
#             0.6507936507936508
#         ],
#         [
#             "CM ",
#             176,
#             0.3492063492063492
#         ]
#     ]
# }
# NumericProfiles for column: SafetyStockLevel: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 6,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "100",
#             97,
#             0.19246031746031747
#         ],
#         [
#             "4",
#             54,
#             0.10714285714285714
#         ],
#         [
#             "500",
#             167,
#             0.33134920634920634
#         ],
#         [
#             "60",
#             5,
#             0.00992063492063492
#         ],
#         [
#             "800",
#             25,
#             0.0496031746031746
#         ],
#         [
#             "1000",
#             156,
#             0.30952380952380953
#         ]
#     ],
#     "kll": "None",
#     "mean": 535.1507936507936,
#     "maximum": 1000.0,
#     "minimum": 4.0,
#     "sum": 269716.0,
#     "stdDev": 373.7416255357439,
#     "approxPercentiles": []
# }
# NumericProfiles for column: ListPrice: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 104,
#     "dataType": "Fractional",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null,
#     "kll": "None",
#     "mean": 438.66624999999937,
#     "maximum": 3578.27,
#     "minimum": 0.0,
#     "sum": 221087.7899999997,
#     "stdDev": 772.8349984287421,
#     "approxPercentiles": []
# }
# StandardProfiles for column: Size: {
#     "completeness": 0.41865079365079366,
#     "approximateNumDistinctValues": 18,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 177,
#         "Unknown": 293,
#         "String": 34
#     },
#     "histogram": [
#         [
#             "62",
#             11,
#             0.021825396825396824
#         ],
#         [
#             "40",
#             11,
#             0.021825396825396824
#         ],
#         [
#             "NullValue",
#             293,
#             0.5813492063492064
#         ],
#         [
#             "44",
#             29,
#             0.057539682539682536
#         ],
#         [
#             "XL",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "56",
#             2,
#             0.003968253968253968
#         ],
#         [
#             "50",
#             9,
#             0.017857142857142856
#         ],
#         [
#             "46",
#             11,
#             0.021825396825396824
#         ],
#         [
#             "M",
#             11,
#             0.021825396825396824
#         ],
#         [
#             "48",
#             25,
#             0.0496031746031746
#         ],
#         [
#             "54",
#             9,
#             0.017857142857142856
#         ],
#         [
#             "L",
#             11,
#             0.021825396825396824
#         ],
#         [
#             "60",
#             11,
#             0.021825396825396824
#         ],
#         [
#             "58",
#             15,
#             0.02976190476190476
#         ],
#         [
#             "42",
#             15,
#             0.02976190476190476
#         ],
#         [
#             "70",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "38",
#             12,
#             0.023809523809523808
#         ],
#         [
#             "52",
#             16,
#             0.031746031746031744
#         ],
#         [
#             "S",
#             9,
#             0.017857142857142856
#         ]
#     ]
# }
# NumericProfiles for column: DaysToManufacture: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 4,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "2",
#             7,
#             0.013888888888888888
#         ],
#         [
#             "1",
#             154,
#             0.3055555555555556
#         ],
#         [
#             "4",
#             97,
#             0.19246031746031747
#         ],
#         [
#             "0",
#             246,
#             0.4880952380952381
#         ]
#     ],
#     "kll": "None",
#     "mean": 1.1031746031746033,
#     "maximum": 4.0,
#     "minimum": 0.0,
#     "sum": 556.0,
#     "stdDev": 1.4911344625441227,
#     "approxPercentiles": []
# }
# StandardProfiles for column: SellStartDate: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 4,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null
# }
# StandardProfiles for column: MakeFlag: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 2,
#     "dataType": "Boolean",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "false",
#             265,
#             0.5257936507936508
#         ],
#         [
#             "true",
#             239,
#             0.4742063492063492
#         ]
#     ]
# }
# NumericProfiles for column: ProductSubcategoryID: {
#     "completeness": 0.5853174603174603,
#     "approximateNumDistinctValues": 37,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "34",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "12",
#             28,
#             0.05555555555555555
#         ],
#         [
#             "8",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "19",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "23",
#             4,
#             0.007936507936507936
#         ],
#         [
#             "4",
#             8,
#             0.015873015873015872
#         ],
#         [
#             "15",
#             9,
#             0.017857142857142856
#         ],
#         [
#             "11",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "9",
#             2,
#             0.003968253968253968
#         ],
#         [
#             "NullValue",
#             209,
#             0.4146825396825397
#         ],
#         [
#             "33",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "22",
#             7,
#             0.013888888888888888
#         ],
#         [
#             "26",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "37",
#             11,
#             0.021825396825396824
#         ],
#         [
#             "13",
#             7,
#             0.013888888888888888
#         ],
#         [
#             "24",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "35",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "16",
#             18,
#             0.03571428571428571
#         ],
#         [
#             "5",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "10",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "21",
#             8,
#             0.015873015873015872
#         ],
#         [
#             "32",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "6",
#             2,
#             0.003968253968253968
#         ],
#         [
#             "36",
#             2,
#             0.003968253968253968
#         ],
#         [
#             "1",
#             32,
#             0.06349206349206349
#         ],
#         [
#             "17",
#             14,
#             0.027777777777777776
#         ],
#         [
#             "25",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "14",
#             33,
#             0.06547619047619048
#         ],
#         [
#             "31",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "20",
#             6,
#             0.011904761904761904
#         ],
#         [
#             "27",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "2",
#             43,
#             0.08531746031746032
#         ],
#         [
#             "18",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "30",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "7",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "29",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "3",
#             22,
#             0.04365079365079365
#         ],
#         [
#             "28",
#             3,
#             0.005952380952380952
#         ]
#     ],
#     "kll": "None",
#     "mean": 12.294915254237289,
#     "maximum": 37.0,
#     "minimum": 1.0,
#     "sum": 3627.0,
#     "stdDev": 9.84340825170669,
#     "approxPercentiles": []
# }
# NumericProfiles for column: Weight: {
#     "completeness": 0.40674603174603174,
#     "approximateNumDistinctValues": 124,
#     "dataType": "Fractional",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null,
#     "kll": "None",
#     "mean": 74.06921951219512,
#     "maximum": 1050.0,
#     "minimum": 2.12,
#     "sum": 15184.19,
#     "stdDev": 181.72173631984197,
#     "approxPercentiles": []
# }
# StandardProfiles for column: WeightUnitMeasureCode: {
#     "completeness": 0.40674603174603174,
#     "approximateNumDistinctValues": 2,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 299,
#         "String": 205
#     },
#     "histogram": [
#         [
#             "G  ",
#             29,
#             0.057539682539682536
#         ],
#         [
#             "NullValue",
#             299,
#             0.5932539682539683
#         ],
#         [
#             "LB ",
#             176,
#             0.3492063492063492
#         ]
#     ]
# }
# StandardProfiles for column: ProductNumber: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 481,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 504
#     },
#     "histogram": null
# }
# StandardProfiles for column: FinishedGoodsFlag: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 2,
#     "dataType": "Boolean",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "false",
#             209,
#             0.4146825396825397
#         ],
#         [
#             "true",
#             295,
#             0.5853174603174603
#         ]
#     ]
# }
# StandardProfiles for column: Class: {
#     "completeness": 0.49007936507936506,
#     "approximateNumDistinctValues": 3,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 257,
#         "String": 247
#     },
#     "histogram": [
#         [
#             "NullValue",
#             257,
#             0.5099206349206349
#         ],
#         [
#             "M ",
#             68,
#             0.1349206349206349
#         ],
#         [
#             "H ",
#             82,
#             0.1626984126984127
#         ],
#         [
#             "L ",
#             97,
#             0.19246031746031747
#         ]
#     ]
# }
# NumericProfiles for column: ProductModelID: {
#     "completeness": 0.5853174603174603,
#     "approximateNumDistinctValues": 115,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "45",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "98",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "113",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "34",
#             8,
#             0.015873015873015872
#         ],
#         [
#             "67",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "120",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "93",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "12",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "66",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "89",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "51",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "124",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "84",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "8",
#             10,
#             0.01984126984126984
#         ],
#         [
#             "78",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "19",
#             8,
#             0.015873015873015872
#         ],
#         [
#             "100",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "23",
#             10,
#             0.01984126984126984
#         ],
#         [
#             "62",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "128",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "4",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "121",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "88",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "77",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "110",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "15",
#             5,
#             0.00992063492063492
#         ],
#         [
#             "11",
#             4,
#             0.007936507936507936
#         ],
#         [
#             "104",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "90",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "9",
#             12,
#             0.023809523809523808
#         ],
#         [
#             "NullValue",
#             209,
#             0.4146825396825397
#         ],
#         [
#             "44",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "33",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "117",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "22",
#             4,
#             0.007936507936507936
#         ],
#         [
#             "56",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "55",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "26",
#             8,
#             0.015873015873015872
#         ],
#         [
#             "50",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "123",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "37",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "68",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "61",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "107",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "13",
#             4,
#             0.007936507936507936
#         ],
#         [
#             "46",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "99",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "24",
#             2,
#             0.003968253968253968
#         ],
#         [
#             "94",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "83",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "35",
#             4,
#             0.007936507936507936
#         ],
#         [
#             "16",
#             5,
#             0.00992063492063492
#         ],
#         [
#             "79",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "5",
#             10,
#             0.01984126984126984
#         ],
#         [
#             "103",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "112",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "10",
#             10,
#             0.01984126984126984
#         ],
#         [
#             "59",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "87",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "48",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "21",
#             4,
#             0.007936507936507936
#         ],
#         [
#             "116",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "54",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "43",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "127",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "65",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "57",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "108",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "32",
#             4,
#             0.007936507936507936
#         ],
#         [
#             "80",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "106",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "82",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "49",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "6",
#             11,
#             0.021825396825396824
#         ],
#         [
#             "126",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "36",
#             10,
#             0.01984126984126984
#         ],
#         [
#             "1",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "17",
#             5,
#             0.00992063492063492
#         ],
#         [
#             "25",
#             5,
#             0.00992063492063492
#         ],
#         [
#             "60",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "14",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "47",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "122",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "111",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "102",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "31",
#             4,
#             0.007936507936507936
#         ],
#         [
#             "96",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "69",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "95",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "58",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "64",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "53",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "42",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "115",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "109",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "20",
#             6,
#             0.011904761904761904
#         ],
#         [
#             "27",
#             4,
#             0.007936507936507936
#         ],
#         [
#             "70",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "2",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "86",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "38",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "81",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "118",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "92",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "125",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "18",
#             2,
#             0.003968253968253968
#         ],
#         [
#             "101",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "30",
#             12,
#             0.023809523809523808
#         ],
#         [
#             "7",
#             8,
#             0.015873015873015872
#         ],
#         [
#             "97",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "114",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "29",
#             5,
#             0.00992063492063492
#         ],
#         [
#             "105",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "63",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "3",
#             3,
#             0.005952380952380952
#         ],
#         [
#             "91",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "52",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "85",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "28",
#             5,
#             0.00992063492063492
#         ],
#         [
#             "119",
#             1,
#             0.001984126984126984
#         ]
#     ],
#     "kll": "None",
#     "mean": 37.44406779661017,
#     "maximum": 128.0,
#     "minimum": 1.0,
#     "sum": 11046.0,
#     "stdDev": 33.96772282067969,
#     "approxPercentiles": []
# }
# StandardProfiles for column: DiscontinuedDate: {
#     "completeness": 0.0,
#     "approximateNumDistinctValues": 0,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null
# }
# StandardProfiles for column: Style: {
#     "completeness": 0.41865079365079366,
#     "approximateNumDistinctValues": 3,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 293,
#         "String": 211
#     },
#     "histogram": [
#         [
#             "U ",
#             176,
#             0.3492063492063492
#         ],
#         [
#             "W ",
#             28,
#             0.05555555555555555
#         ],
#         [
#             "NullValue",
#             293,
#             0.5813492063492064
#         ],
#         [
#             "M ",
#             7,
#             0.013888888888888888
#         ]
#     ]
# }
# NumericProfiles for column: ProductID: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 510,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null,
#     "kll": "None",
#     "mean": 673.0396825396825,
#     "maximum": 999.0,
#     "minimum": 1.0,
#     "sum": 339212.0,
#     "stdDev": 229.1454761040394,
#     "approxPercentiles": []
# }
# StandardProfiles for column: Color: {
#     "completeness": 0.5079365079365079,
#     "approximateNumDistinctValues": 9,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 248,
#         "String": 256
#     },
#     "histogram": [
#         [
#             "Yellow",
#             36,
#             0.07142857142857142
#         ],
#         [
#             "NullValue",
#             248,
#             0.49206349206349204
#         ],
#         [
#             "Multi",
#             8,
#             0.015873015873015872
#         ],
#         [
#             "Red",
#             38,
#             0.07539682539682539
#         ],
#         [
#             "Blue",
#             26,
#             0.051587301587301584
#         ],
#         [
#             "White",
#             4,
#             0.007936507936507936
#         ],
#         [
#             "Black",
#             93,
#             0.18452380952380953
#         ],
#         [
#             "Grey",
#             1,
#             0.001984126984126984
#         ],
#         [
#             "Silver/Black",
#             7,
#             0.013888888888888888
#         ],
#         [
#             "Silver",
#             43,
#             0.08531746031746032
#         ]
#     ]
# }
# StandardProfiles for column: SellEndDate: {
#     "completeness": 0.19444444444444445,
#     "approximateNumDistinctValues": 2,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null
# }
# NumericProfiles for column: StandardCost: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 110,
#     "dataType": "Fractional",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null,
#     "kll": "None",
#     "mean": 258.60296130952383,
#     "maximum": 2171.2942,
#     "minimum": 0.0,
#     "sum": 130335.89250000002,
#     "stdDev": 461.17461124084446,
#     "approxPercentiles": []
# }

# %%
### Constraint Suggestions section
# TODO find meaninful constraints here

from pydeequ.suggestions import *

suggestionResult = ConstraintSuggestionRunner(spark) \
             .onData(df) \
             .addConstraintRule(DEFAULT()) \
             .run()

print
for sugg in suggestionResult['constraint_suggestions']:
    print(f"Constraint suggestion for \'{sugg['column_name']}\': {sugg['description']}")
    print(f"The corresponding Python code is: {sugg['code_for_constraint']}\n")
# Out:
# Constraint suggestion for 'ModifiedDate': 'ModifiedDate' is not null
# The corresponding Python code is: .isComplete("ModifiedDate")
#
# Constraint suggestion for 'ReorderPoint': 'ReorderPoint' has value range '375', '750', '75', '3', '600', '45'
# The corresponding Python code is: .isContainedIn("ReorderPoint", ["375", "750", "75", "3", "600", "45"])
#
# Constraint suggestion for 'ReorderPoint': 'ReorderPoint' is not null
# The corresponding Python code is: .isComplete("ReorderPoint")
#
# Constraint suggestion for 'ReorderPoint': 'ReorderPoint' has value range '375', '750', '75', '3' for at least 91.0% of values
# The corresponding Python code is: .isContainedIn("ReorderPoint", ["375", "750", "75", "3"], lambda x: x >= 0.91, "It should be above 0.91!")
#
# Constraint suggestion for 'ReorderPoint': 'ReorderPoint' has no negative values
# The corresponding Python code is: .isNonNegative("ReorderPoint")
#
# Constraint suggestion for 'ProductLine': 'ProductLine' has value range 'R ', 'M ', 'T ', 'S '
# The corresponding Python code is: .isContainedIn("ProductLine", ["R ", "M ", "T ", "S "])
#
# Constraint suggestion for 'ProductLine': 'ProductLine' has value range 'R ', 'M ', 'T ' for at least 90.0% of values
# The corresponding Python code is: .isContainedIn("ProductLine", ["R ", "M ", "T "], lambda x: x >= 0.9, "It should be above 0.9!")
#
# Constraint suggestion for 'ProductLine': 'ProductLine' has less than 50% missing values
# The corresponding Python code is: .hasCompleteness("ProductLine", lambda x: x >= 0.5, "It should be above 0.5!")
#
# Constraint suggestion for 'Name': 'Name' is not null
# The corresponding Python code is: .isComplete("Name")
#
# Constraint suggestion for 'Name': 'Name' is unique
# The corresponding Python code is: .isUnique("Name")
#
# Constraint suggestion for 'rowguid': 'rowguid' is not null
# The corresponding Python code is: .isComplete("rowguid")
#
# Constraint suggestion for 'rowguid': 'rowguid' is unique
# The corresponding Python code is: .isUnique("rowguid")
#
# Constraint suggestion for 'SizeUnitMeasureCode': 'SizeUnitMeasureCode' has value range 'CM '
# The corresponding Python code is: .isContainedIn("SizeUnitMeasureCode", ["CM "])
#
# Constraint suggestion for 'SizeUnitMeasureCode': 'SizeUnitMeasureCode' has less than 70% missing values
# The corresponding Python code is: .hasCompleteness("SizeUnitMeasureCode", lambda x: x >= 0.3, "It should be above 0.3!")
#
# Constraint suggestion for 'SafetyStockLevel': 'SafetyStockLevel' has value range '500', '1000', '100', '4', '800', '60'
# The corresponding Python code is: .isContainedIn("SafetyStockLevel", ["500", "1000", "100", "4", "800", "60"])
#
# Constraint suggestion for 'SafetyStockLevel': 'SafetyStockLevel' is not null
# The corresponding Python code is: .isComplete("SafetyStockLevel")
#
# Constraint suggestion for 'SafetyStockLevel': 'SafetyStockLevel' has value range '500', '1000', '100', '4' for at least 91.0% of values
# The corresponding Python code is: .isContainedIn("SafetyStockLevel", ["500", "1000", "100", "4"], lambda x: x >= 0.91, "It should be above 0.91!")
#
# Constraint suggestion for 'SafetyStockLevel': 'SafetyStockLevel' has no negative values
# The corresponding Python code is: .isNonNegative("SafetyStockLevel")
#
# Constraint suggestion for 'ListPrice': 'ListPrice' is not null
# The corresponding Python code is: .isComplete("ListPrice")
#
# Constraint suggestion for 'ListPrice': 'ListPrice' has no negative values
# The corresponding Python code is: .isNonNegative("ListPrice")
#
# Constraint suggestion for 'Size': 'Size' has value range '44', '48', '52', '42', '58', '38', '60', 'L', 'M', '46', '40', '62', 'S', '54', '50', 'XL', '56', '70'
# The corresponding Python code is: .isContainedIn("Size", ["44", "48", "52", "42", "58", "38", "60", "L", "M", "46", "40", "62", "S", "54", "50", "XL", "56", "70"])
#
# Constraint suggestion for 'Size': 'Size' has value range '44', '48', '52', '42', '58', '38', '60', 'L', 'M', '46', '40' for at least 88.0% of values
# The corresponding Python code is: .isContainedIn("Size", ["44", "48", "52", "42", "58", "38", "60", "L", "M", "46", "40"], lambda x: x >= 0.88, "It should be above 0.88!")
#
# Constraint suggestion for 'Size': 'Size' has less than 63% missing values
# The corresponding Python code is: .hasCompleteness("Size", lambda x: x >= 0.37, "It should be above 0.37!")
#
# Constraint suggestion for 'DaysToManufacture': 'DaysToManufacture' has value range '0', '1', '4', '2'
# The corresponding Python code is: .isContainedIn("DaysToManufacture", ["0", "1", "4", "2"])
#
# Constraint suggestion for 'DaysToManufacture': 'DaysToManufacture' is not null
# The corresponding Python code is: .isComplete("DaysToManufacture")
#
# Constraint suggestion for 'DaysToManufacture': 'DaysToManufacture' has value range '0', '1', '4' for at least 97.0% of values
# The corresponding Python code is: .isContainedIn("DaysToManufacture", ["0", "1", "4"], lambda x: x >= 0.97, "It should be above 0.97!")
#
# Constraint suggestion for 'DaysToManufacture': 'DaysToManufacture' has no negative values
# The corresponding Python code is: .isNonNegative("DaysToManufacture")
#
# Constraint suggestion for 'SellStartDate': 'SellStartDate' is not null
# The corresponding Python code is: .isComplete("SellStartDate")
#
# Constraint suggestion for 'MakeFlag': 'MakeFlag' is not null
# The corresponding Python code is: .isComplete("MakeFlag")
#
# Constraint suggestion for 'ProductSubcategoryID': 'ProductSubcategoryID' has value range '2', '14', '1', '12', '3', '16', '17', '37', '15', '21', '4', '13', '22', '20' for at least 87.0% of values
# The corresponding Python code is: .isContainedIn("ProductSubcategoryID", ["2", "14", "1", "12", "3", "16", "17", "37", "15", "21", "4", "13", "22", "20"], lambda x: x >= 0.87, "It should be above 0.87!")
#
# Constraint suggestion for 'ProductSubcategoryID': 'ProductSubcategoryID' has no negative values
# The corresponding Python code is: .isNonNegative("ProductSubcategoryID")
#
# Constraint suggestion for 'ProductSubcategoryID': 'ProductSubcategoryID' has less than 46% missing values
# The corresponding Python code is: .hasCompleteness("ProductSubcategoryID", lambda x: x >= 0.54, "It should be above 0.54!")
#
# Constraint suggestion for 'Weight': 'Weight' has no negative values
# The corresponding Python code is: .isNonNegative("Weight")
#
# Constraint suggestion for 'Weight': 'Weight' has less than 64% missing values
# The corresponding Python code is: .hasCompleteness("Weight", lambda x: x >= 0.36, "It should be above 0.36!")
#
# Constraint suggestion for 'WeightUnitMeasureCode': 'WeightUnitMeasureCode' has value range 'LB ', 'G  '
# The corresponding Python code is: .isContainedIn("WeightUnitMeasureCode", ["LB ", "G  "])
#
# Constraint suggestion for 'WeightUnitMeasureCode': 'WeightUnitMeasureCode' has value range 'LB ' for at least 92.0% of values
# The corresponding Python code is: .isContainedIn("WeightUnitMeasureCode", ["LB "], lambda x: x >= 0.92, "It should be above 0.92!")
#
# Constraint suggestion for 'WeightUnitMeasureCode': 'WeightUnitMeasureCode' has less than 64% missing values
# The corresponding Python code is: .hasCompleteness("WeightUnitMeasureCode", lambda x: x >= 0.36, "It should be above 0.36!")
#
# Constraint suggestion for 'ProductNumber': 'ProductNumber' is not null
# The corresponding Python code is: .isComplete("ProductNumber")
#
# Constraint suggestion for 'ProductNumber': 'ProductNumber' is unique
# The corresponding Python code is: .isUnique("ProductNumber")
#
# Constraint suggestion for 'FinishedGoodsFlag': 'FinishedGoodsFlag' is not null
# The corresponding Python code is: .isComplete("FinishedGoodsFlag")
#
# Constraint suggestion for 'Class': 'Class' has value range 'L ', 'H ', 'M '
# The corresponding Python code is: .isContainedIn("Class", ["L ", "H ", "M "])
#
# Constraint suggestion for 'Class': 'Class' has value range 'L ', 'H ', 'M ' for at least 99.0% of values
# The corresponding Python code is: .isContainedIn("Class", ["L ", "H ", "M "], lambda x: x >= 0.99, "It should be above 0.99!")
#
# Constraint suggestion for 'Class': 'Class' has less than 56% missing values
# The corresponding Python code is: .hasCompleteness("Class", lambda x: x >= 0.44, "It should be above 0.44!")
#
# Constraint suggestion for 'ProductModelID': 'ProductModelID' has no negative values
# The corresponding Python code is: .isNonNegative("ProductModelID")
#
# Constraint suggestion for 'ProductModelID': 'ProductModelID' has less than 46% missing values
# The corresponding Python code is: .hasCompleteness("ProductModelID", lambda x: x >= 0.54, "It should be above 0.54!")
#
# Constraint suggestion for 'Style': 'Style' has value range 'U ', 'W ', 'M '
# The corresponding Python code is: .isContainedIn("Style", ["U ", "W ", "M "])
#
# Constraint suggestion for 'Style': 'Style' has value range 'U ' for at least 90.0% of values
# The corresponding Python code is: .isContainedIn("Style", ["U "], lambda x: x >= 0.9, "It should be above 0.9!")
#
# Constraint suggestion for 'Style': 'Style' has less than 63% missing values
# The corresponding Python code is: .hasCompleteness("Style", lambda x: x >= 0.37, "It should be above 0.37!")
#
# Constraint suggestion for 'ProductID': 'ProductID' is not null
# The corresponding Python code is: .isComplete("ProductID")
#
# Constraint suggestion for 'ProductID': 'ProductID' has no negative values
# The corresponding Python code is: .isNonNegative("ProductID")
#
# Constraint suggestion for 'ProductID': 'ProductID' is unique
# The corresponding Python code is: .isUnique("ProductID")
#
# Constraint suggestion for 'Color': 'Color' has value range 'Black', 'Silver', 'Red', 'Yellow', 'Blue', 'Multi', 'Silver/Black', 'White', 'Grey'
# The corresponding Python code is: .isContainedIn("Color", ["Black", "Silver", "Red", "Yellow", "Blue", "Multi", "Silver/Black", "White", "Grey"])
#
# Constraint suggestion for 'Color': 'Color' has value range 'Black', 'Silver', 'Red', 'Yellow' for at least 88.0% of values
# The corresponding Python code is: .isContainedIn("Color", ["Black", "Silver", "Red", "Yellow"], lambda x: x >= 0.88, "It should be above 0.88!")
#
# Constraint suggestion for 'Color': 'Color' has less than 54% missing values
# The corresponding Python code is: .hasCompleteness("Color", lambda x: x >= 0.46, "It should be above 0.46!")
#
# Constraint suggestion for 'StandardCost': 'StandardCost' is not null
# The corresponding Python code is: .isComplete("StandardCost")
#
# Constraint suggestion for 'StandardCost': 'StandardCost' has no negative values
# The corresponding Python code is: .isNonNegative("StandardCost")

# %%
### Constraint Verification section
# TODO check selected constraints here and make beautify the report

from pydeequ.checks import *
from pydeequ.verification import *

check = Check(spark, CheckLevel.Warning, "Review Check")

checkResult = VerificationSuite(spark) \
    .onData(df) \
    .addCheck(
        check.isUnique("rowguid") \
        .isComplete("rowguid") \
        .isUnique("ProductID")  \
        .isUnique("Name") \
        .isComplete("Name") \
        .isNonNegative("Weight")  \
        .isNonNegative("ListPrice") \
        .isContainedIn("DaysToManufacture", ["0", "1", "2", "3", "4"])) \
    .run()

checkResult_df = VerificationResult.checkResultsAsDataFrame(spark, checkResult)
checkResult_df.show()
# Out:
# +------------+-----------+------------+--------------------+-----------------+------------------+
# |       check|check_level|check_status|          constraint|constraint_status|constraint_message|
# +------------+-----------+------------+--------------------+-----------------+------------------+
# |Review Check|    Warning|     Success|UniquenessConstra...|          Success|                  |
# |Review Check|    Warning|     Success|CompletenessConst...|          Success|                  |
# |Review Check|    Warning|     Success|UniquenessConstra...|          Success|                  |
# |Review Check|    Warning|     Success|UniquenessConstra...|          Success|                  |
# |Review Check|    Warning|     Success|CompletenessConst...|          Success|                  |
# |Review Check|    Warning|     Success|ComplianceConstra...|          Success|                  |
# |Review Check|    Warning|     Success|ComplianceConstra...|          Success|                  |
# |Review Check|    Warning|     Success|ComplianceConstra...|          Success|                  |
# +------------+-----------+------------+--------------------+-----------------+------------------+

# %%
import pandas as pd

pandasDF = checkResult_df.toPandas()

# Apply CSS styling to df
pandasDF.drop('check_level', inplace=True, axis=1)
formated_df = pandasDF.style.applymap(lambda x: 'background-color : red' if x == 'Failure' else 
                                          ('background-color : yellow' if x == 'Warning' else 
                                               ('background-color : green' if x == 'Success' else '')))

display(formated_df)
# Convert the DataFrame into an HTML table and write it to a file
html_table = formated_df.render()
with open("report.html", "w") as f:
    f.write(html_table)
# Out:
# <style  type="text/css" >
# #T_d326dc02_e471_11ed_ba17_0242ac110002row0_col1,#T_d326dc02_e471_11ed_ba17_0242ac110002row0_col3,#T_d326dc02_e471_11ed_ba17_0242ac110002row1_col1,#T_d326dc02_e471_11ed_ba17_0242ac110002row1_col3,#T_d326dc02_e471_11ed_ba17_0242ac110002row2_col1,#T_d326dc02_e471_11ed_ba17_0242ac110002row2_col3,#T_d326dc02_e471_11ed_ba17_0242ac110002row3_col1,#T_d326dc02_e471_11ed_ba17_0242ac110002row3_col3,#T_d326dc02_e471_11ed_ba17_0242ac110002row4_col1,#T_d326dc02_e471_11ed_ba17_0242ac110002row4_col3,#T_d326dc02_e471_11ed_ba17_0242ac110002row5_col1,#T_d326dc02_e471_11ed_ba17_0242ac110002row5_col3,#T_d326dc02_e471_11ed_ba17_0242ac110002row6_col1,#T_d326dc02_e471_11ed_ba17_0242ac110002row6_col3,#T_d326dc02_e471_11ed_ba17_0242ac110002row7_col1,#T_d326dc02_e471_11ed_ba17_0242ac110002row7_col3{
#             background-color :  green;
#         }</style><table id="T_d326dc02_e471_11ed_ba17_0242ac110002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >check</th>        <th class="col_heading level0 col1" >check_status</th>        <th class="col_heading level0 col2" >constraint</th>        <th class="col_heading level0 col3" >constraint_status</th>        <th class="col_heading level0 col4" >constraint_message</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d326dc02_e471_11ed_ba17_0242ac110002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row0_col0" class="data row0 col0" >Review Check</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row0_col1" class="data row0 col1" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row0_col2" class="data row0 col2" >UniquenessConstraint(Uniqueness(List(rowguid),None))</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row0_col3" class="data row0 col3" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row0_col4" class="data row0 col4" ></td>
#             </tr>
#             <tr>
#                         <th id="T_d326dc02_e471_11ed_ba17_0242ac110002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row1_col0" class="data row1 col0" >Review Check</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row1_col1" class="data row1 col1" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row1_col2" class="data row1 col2" >CompletenessConstraint(Completeness(rowguid,None))</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row1_col3" class="data row1 col3" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row1_col4" class="data row1 col4" ></td>
#             </tr>
#             <tr>
#                         <th id="T_d326dc02_e471_11ed_ba17_0242ac110002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row2_col0" class="data row2 col0" >Review Check</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row2_col1" class="data row2 col1" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row2_col2" class="data row2 col2" >UniquenessConstraint(Uniqueness(List(ProductID),None))</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row2_col3" class="data row2 col3" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row2_col4" class="data row2 col4" ></td>
#             </tr>
#             <tr>
#                         <th id="T_d326dc02_e471_11ed_ba17_0242ac110002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row3_col0" class="data row3 col0" >Review Check</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row3_col1" class="data row3 col1" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row3_col2" class="data row3 col2" >UniquenessConstraint(Uniqueness(List(Name),None))</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row3_col3" class="data row3 col3" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row3_col4" class="data row3 col4" ></td>
#             </tr>
#             <tr>
#                         <th id="T_d326dc02_e471_11ed_ba17_0242ac110002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row4_col0" class="data row4 col0" >Review Check</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row4_col1" class="data row4 col1" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row4_col2" class="data row4 col2" >CompletenessConstraint(Completeness(Name,None))</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row4_col3" class="data row4 col3" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row4_col4" class="data row4 col4" ></td>
#             </tr>
#             <tr>
#                         <th id="T_d326dc02_e471_11ed_ba17_0242ac110002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row5_col0" class="data row5 col0" >Review Check</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row5_col1" class="data row5 col1" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row5_col2" class="data row5 col2" >ComplianceConstraint(Compliance(Weight is non-negative,COALESCE(CAST(Weight AS DECIMAL(20,10)), 0.0) >= 0,None))</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row5_col3" class="data row5 col3" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row5_col4" class="data row5 col4" ></td>
#             </tr>
#             <tr>
#                         <th id="T_d326dc02_e471_11ed_ba17_0242ac110002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row6_col0" class="data row6 col0" >Review Check</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row6_col1" class="data row6 col1" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row6_col2" class="data row6 col2" >ComplianceConstraint(Compliance(ListPrice is non-negative,COALESCE(CAST(ListPrice AS DECIMAL(20,10)), 0.0) >= 0,None))</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row6_col3" class="data row6 col3" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row6_col4" class="data row6 col4" ></td>
#             </tr>
#             <tr>
#                         <th id="T_d326dc02_e471_11ed_ba17_0242ac110002level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row7_col0" class="data row7 col0" >Review Check</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row7_col1" class="data row7 col1" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row7_col2" class="data row7 col2" >ComplianceConstraint(Compliance(DaysToManufacture contained in 0,1,2,3,4,`DaysToManufacture` IS NULL OR `DaysToManufacture` IN ('0','1','2','3','4'),None))</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row7_col3" class="data row7 col3" >Success</td>
#                         <td id="T_d326dc02_e471_11ed_ba17_0242ac110002row7_col4" class="data row7 col4" ></td>
#             </tr>
#     </tbody></table>
